# %% [markdown]
# <a href="https://colab.research.google.com/github/purnaa-l/ML-Models/blob/main/Position_versus_Salary_Polynomial_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color='Blue')
plt.title('Position versus Salary')
plt.xlabel('Pos')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_train, regressor.predict(X_train), color='Blue')
plt.title('Position versus Salary')
plt.xlabel('Pos')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=4)
X_poly=poly_reg.fit_transform(X)
lin_reg=LinearRegression()
lin_reg.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color='red')
plt.plot(X, lin_reg.predict(poly_reg.fit_transform(X)), color='blue')  # Predict using transformed data
plt.title('Position versus Salary')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %%
regressor.predict([[6.5]])
# Out:
# array([335474.55968689])

# %% [markdown]
# The above is a prediction using Linear Regression

# %%
lin_reg.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])

# %% [markdown]
# More accurate prediction using Polynomial Linear Regression
